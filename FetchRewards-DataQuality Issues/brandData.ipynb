# %%
# Import python Library
import pandas as pd
import numpy as np 
import json
import flat_table
from flatten_json import flatten
#pd.set_option('display.max_columns', None)# To display maximm number of Columns in the data.
# pd.set_option('display.max_rows', None) # To display maximm number of Rows in the data.

# %%
# Import unstructured brandData from local machine
brands = []
for line in open('C:/Users/patel/Desktop/FetchRewards/brands.json','r'):
    brands.append(json.loads(line))
brands
# Out:
# [{'_id': {'$oid': '601ac115be37ce2ead437551'},
#   'barcode': '511111019862',
#   'category': 'Baking',
#   'categoryCode': 'BAKING',
#   'cpg': {'$id': {'$oid': '601ac114be37ce2ead437550'}, '$ref': 'Cogs'},
#   'name': 'test brand @1612366101024',
#   'topBrand': False},
#  {'_id': {'$oid': '601c5460be37ce2ead43755f'},
#   'barcode': '511111519928',
#   'brandCode': 'STARBUCKS',
#   'category': 'Beverages',
#   'categoryCode': 'BEVERAGES',
#   'cpg': {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, '$ref': 'Cogs'},
#   'name': 'Starbucks',
#   'topBrand': False},
#  {'_id': {'$oid': '601ac142be37ce2ead43755d'},
#   'barcode': '511111819905',
#   'brandCode': 'TEST BRANDCODE @1612366146176',
#   'category': 'Baking',
#   'categoryCode': 'BAKING',
#   'cpg': {'$id': {'$oid': '601ac142be37ce2ead437559'}, '$ref': 'Cogs'},
#   'name': 'test brand @1612366146176',
#   'topBrand': False},
#  {'_id': {'$oid': '601ac142be37ce2ead43755a'},
#   'barcode': '511111519874',
# ...

# %%
#Converting Json Data to DataFrame for better visualization of Data
brandsData = pd.json_normalize(brands)
brandsData
# Out:
#            barcode            category      categoryCode  \
# 0     511111019862              Baking            BAKING
# 1     511111519928           Beverages         BEVERAGES
# 2     511111819905              Baking            BAKING
# 3     511111519874              Baking            BAKING
# 4     511111319917      Candy & Sweets  CANDY_AND_SWEETS
# ...            ...                 ...               ...
# 1162  511111116752              Baking            BAKING
# 1163  511111706328  Breakfast & Cereal               NaN
# 1164  511111416173      Candy & Sweets  CANDY_AND_SWEETS
# 1165  511111400608             Grocery               NaN
# 1166  511111019930              Baking            BAKING
#
#                            name topBrand                  _id.$oid  \
# 0     test brand @1612366101024    False  601ac115be37ce2ead437551
# 1                     Starbucks    False  601c5460be37ce2ead43755f
# 2     test brand @1612366146176    False  601ac142be37ce2ead43755d
# ...

# %%
# return how many rows and columns exist in a dataset and Print a data frame total number of Rows and Columns Respectively.
brandsData.shape
# Out:
# (1167, 9)

# %%
#Total Count for missing values in each column of dataFrame
brandsData.isnull().sum()
# Out:
# barcode           0
# category        155
# categoryCode    650
# name              0
# topBrand        612
# _id.$oid          0
# cpg.$id.$oid      0
# cpg.$ref          0
# brandCode       234
# dtype: int64

# %%
#Data Quality issues with brandData
#1. More that 55% of the data is missing from the categoryCode column which is a major data Quality issue.
#2. More that 50% of the data is missing from the categoryCode column which is a data Quality issue.
#3. 20% of the data is missing from the brandCode Column, missing code for the brand is a quality issue.

# %%
# Checking the Unique Values in the Brand Data Table
uniqueValues = brandsData['barcode'].nunique()
print('Number of unique values in column "barcode" of the dataframe : ')
print(uniqueValues)
# Out:
# Number of unique values in column "barcode" of the dataframe :
# 1160

# %%
# Print information, shape, and data type for the data frame
# Give's the Count of non-null values in each Column of the Dataframe
brandsData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1167 entries, 0 to 1166
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   barcode       1167 non-null   object
#  1   category      1012 non-null   object
#  2   categoryCode  517 non-null    object
#  3   name          1167 non-null   object
#  4   topBrand      555 non-null    object
#  5   _id.$oid      1167 non-null   object
#  6   cpg.$id.$oid  1167 non-null   object
#  7   cpg.$ref      1167 non-null   object
#  8   brandCode     933 non-null    object
# dtypes: object(9)
# memory usage: 82.2+ KB

# %%
# Determine count of unique values for each column in the dataframe
brandsData.nunique()
# Out:
# barcode         1160
# category          23
# categoryCode      14
# name            1156
# topBrand           2
# _id.$oid        1167
# cpg.$id.$oid     196
# cpg.$ref           2
# brandCode        897
# dtype: int64
